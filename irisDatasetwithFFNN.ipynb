# %%
from sklearn.datasets import load_iris

# %%
datasets = load_iris()

# %%
data = datasets.data
target = datasets.target

# %%
print(data[:5])
print()
print(target[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
#
# [0 0 0 0 0]

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add (Dense (8, input_dim = 4,activation="relu" ) )
model.add (Dense (8, input_dim=8, activation="relu"))
model.add (Dense (3,input_dim =8,activation="softmax"))

# %%
model.compile(loss = "categorical_crossentropy", optimizer="sgd",metrics=["accuracy"])

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data,train_target,test_target =train_test_split(data,target,test_size = 0.2)

# %%
from tensorflow.keras.utils import to_categorical

# %%
train_target_data = to_categorical(train_target)

# %%
history = model.fit(train_data, train_target_data, epochs=20)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4445 - accuracy: 0.2833
# Epoch 2/20
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1421 - accuracy: 0.3083
# Epoch 3/20
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0678 - accuracy: 0.3083
# Epoch 4/20
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9809 - accuracy: 0.3667
# Epoch 5/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8838 - accuracy: 0.6000
# Epoch 6/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7938 - accuracy: 0.9333
# Epoch 7/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7508 - accuracy: 0.9500
# Epoch 8/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7152 - accuracy: 0.9583
# Epoch 9/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6855 - accuracy: 0.9000
# Epoch 10/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6646 - accuracy: 0.8833
# Epoch 11/20
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6328 - accuracy: 0.9000
# Epoch 12/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6062 - accuracy: 0.9250
# Epoch 13/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.8417
# Epoch 14/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5585 - accuracy: 0.9417
# Epoch 15/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5354 - accuracy: 0.9250
# Epoch 16/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5230 - accuracy: 0.9167
# Epoch 17/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5071 - accuracy: 0.8917
# Epoch 18/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4888 - accuracy: 0.9333
# Epoch 19/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4685 - accuracy: 0.9500
# Epoch 20/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4513 - accuracy: 0.9083

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (history.history ['loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot (history.history ['accuracy'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
print(model.predict(test_data))
# Out:
# [[0.72977763 0.26046073 0.00976161]
#  [0.03325465 0.33135962 0.63538563]
#  [0.14146292 0.59323955 0.26529753]
#  [0.72212183 0.26716474 0.01071335]
#  [0.7032112  0.28137422 0.01541451]
#  [0.03159098 0.48197746 0.48643157]
#  [0.09944282 0.54251724 0.35803992]
#  [0.01336547 0.27691185 0.70972264]
#  [0.16002153 0.60611856 0.23385991]
#  [0.04980133 0.44111124 0.50908744]
#  [0.7033542  0.28219086 0.01445492]
#  [0.66700095 0.31577218 0.01722694]
#  [0.1823902  0.5801153  0.23749448]
#  [0.15241401 0.57115424 0.27643177]
#  [0.1037745  0.58281964 0.31340578]
#  [0.150729   0.5812734  0.2679976 ]
#  [0.08462303 0.5479975  0.36737955]
#  [0.10548358 0.5009313  0.3935851 ]
#  [0.09143459 0.48943463 0.4191308 ]
#  [0.18373683 0.61633676 0.19992642]
#  [0.67958885 0.30044168 0.01996947]
#  [0.02795359 0.31528908 0.65675735]
#  [0.07572434 0.44149905 0.4827767 ]
#  [0.6550101  0.3225003  0.02248965]
#  [0.63375    0.34532896 0.02092102]
#  [0.69363004 0.29002973 0.0163402 ]
#  [0.1049507  0.60495996 0.29008934]
#  [0.25100198 0.57824075 0.17075725]
#  [0.01453971 0.22258992 0.7628704 ]
#  [0.11110664 0.5365591  0.35233426]]
